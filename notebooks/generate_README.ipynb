# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/student_var25/env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/student_var25/env/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/student_var25/env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/student_var25/env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/student_var25/env/lib/python3.10/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/student_var25/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import os

# Путь к файлу
file_path = '../data/diabetes.csv'

# Словарь с описанием признаков
descriptions = {
    'Pregnancies': 'Количество беременностей',
    'Glucose': 'Концентрация глюкозы в плазме',
    'BloodPressure': 'Диастолическое артериальное давление (мм рт.ст.)',
    'SkinThickness': 'Толщина кожной складки трицепса (мм)',
    'Insulin': 'Уровень инсулина в сыворотке крови (мкЕд/мл)',
    'BMI': 'Индекс массы тела (вес в кг / (рост в м)^2)',
    'DiabetesPedigreeFunction': 'Показатель наследственности диабета',
    'Age': 'Возраст (лет)',
    'Outcome': 'Результат (0 - здоров, 1 - болен)'
}

# Проверка наличия файла
if os.path.exists(file_path):
    df = pd.read_csv(file_path)

    content = f"""# Проект: Анализ диабета
Описание: Исследование признаков пациентов для классификации заболеваний.

## Описание данных
- **Количество записей:** {df.shape[0]}
- **Количество признаков:** {df.shape[1]}

| Признак | Описание | Тип | Пропуски | Минимум | Максимум |
| :--- | :--- | :--- | :--- | :--- | :--- |
"""

    for col in df.columns:
        desc = descriptions.get(col, "Нет описания")
        
        nulls = df[col].isnull().sum()
        dtype = df[col].dtype
        v_min = df[col].min()
        v_max = df[col].max()
        
        content += f"| **{col}** | {desc} | `{dtype}` | {nulls} | {v_min} | {v_max} |\n"

    with open('../README.md', 'w', encoding='utf-8') as f:
        f.write(content)

    print("README.md успешно обновлен!")
else:
    print(f"Ошибка: Файл {file_path} не найден.")
# Out:
# README.md успешно обновлен!
